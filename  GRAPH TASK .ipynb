# %%
our dear friend mark who lives in california plays soccer in a club named spinoff.
since he is new to california and he love pets ,he bought a cat .mark is a student who studies in california state univercity (CSU).

# %%
statements
mark love pets.
mark studies in california
mark bought a  cat.
mark is a student

# %%
pip install matplotlip

# %%
pip install networkx

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
graph=nx.DiGraph(Info="mark's Details")

# %%
graph.add_node("mark",pos=(0,0))
graph.add_node("cat",pos=(-2,6))
graph.add_node("student",pos=(2,-5))
graph.add_node("animal",pos=(1,6))
graph.add_node("spinoff",pos=(-5,-5))
graph.add_node("california",pos=(4,6))
graph.add_node("soccer",pos=(-5,2))
graph.add_node("sports",pos=(0,-8))
graph.add_node("CSU",pos=(5,-1))
pos=nx.get_node_attributes(graph,"pos")

# %%
graph.add_edge("mark","cat",weight="has a")
graph.add_edge("mark","student",weight="is a")
graph.add_edge("cat","animal",weight="is a")
graph.add_edge("mark","soccer",weight="plays")
graph.add_edge("mark","california",weight="live")
graph.add_edge("mark","sports",weight="play")
graph.add_edge("mark","CSU",weight="studies in")
graph.add_edge("mark","spinoff",weight="is a club")
weight=nx.get_edge_attributes(graph,"weight")

# %%
plt.figure()
nx.draw_networkx(graph,pos,font_weight="bold",node_size=2000)
nx.draw_networkx_edge_labels(graph,pos,edge_labels=weight)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# {('mark', 'cat'): Text(-1.0, 3.0, 'has a'),
#  ('mark', 'student'): Text(1.0, -2.5, 'is a'),
#  ('mark', 'soccer'): Text(-2.5, 1.0, 'plays'),
#  ('mark', 'california'): Text(2.0, 3.0, 'live'),
#  ('mark', 'sports'): Text(0.0, -4.0, 'play'),
#  ('mark', 'CSU'): Text(2.5, -0.5, 'studies in'),
#  ('mark', 'spinoff'): Text(-2.5, -2.5, 'is a club'),
#  ('cat', 'animal'): Text(-0.5, 6.0, 'is a')}
